# %% [markdown]
# # Profiling of gene sets enriched in genomes with strong IDP propensity in ARF

# %% [markdown]
# Functional annotation was performed with KofamScan (Aramaki et al., Bioinformatics, 2020).
#
# The HMM profiles were downloaded on  Mar. 24, 2021, with the following procedure:
#
# ```{bash}
# # at /nfs_share/yamanouchi/kofamscan210324
# wget ftp://ftp.genome.jp/pub/db/kofam/ko_list.gz
# wget ftp://ftp.genome.jp/pub/db/kofam/profiles.tar.gz
#
# gunzip ko_list.gz
# tar xvfz profiles.tar.gz
# ```
#
# (`ko_list` was copied to the `metadata/` directory.)
#
# Then, the KofamScan annotation pipeline was executed under the following configurations:
#
# ```{bash}
# docker-compose run --rm kofamscan /bin/bash /scripts/210528_kofamscan.sh
# ```
#
# - docker-compose.yml (partial)
#     ```
#     kofamscan:
#     build: ./docker/kofamscan
#     volumes:
#       - ./data:/data
#       - ./scripts:/scripts
#       - /nfs_share/yamanouchi/kofamscan210324:/db
#     ```
#
#
# - docker/kofamscan/Dockerfile
#     ```{Dockerfile}
#     FROM continuumio/miniconda3:4.9.2
#     RUN conda install -c conda-forge -y mamba==0.8.2
#     RUN mamba install -c bioconda -y kofamscan==1.3.0
#     ```
#
#
# - scripts/210528_kofamscan.sh:
#
#     ```{bash}
#     #!/bin/bash -eu
#
#     run_kofamscan () {
#         local infile=$1
#         local outfile=${infile/cds_prot/kofamscan}
#         outfile=${outfile/.faa/.tsv}
#         tmpdir=$(mktemp -d)
#         trap "[[ -d $tmpdir ]] && rm -rf $tmpdir" ERR EXIT
#         exec_annotation -p /db/profiles -k /db/ko_list --cpu 20 --tmp-dir $tmpdir -f detail-tsv $infile > $outfile
#     }
#
#     export -f run_kofamscan
#
#     ls /data/cds_prot/*.faa | xargs -t -P5 -L1 -I{} /bin/bash -c 'run_kofamscan {}'
#     ```

# %%
import pandas as pd
from functools import partial
from tqdm.notebook import tqdm
from pyscripts.config import path2
from pyscripts.datasets import Metadata
metadata = Metadata()

# %%
def load_annot(gcf):
    annot = pd.read_csv(
        path2.data/'kofamscan'/f'{gcf}.tsv', 
        sep='\t', skiprows=2, 
        names=['star', 'gene_name', 'KO', 'threshold', 'score', 'evalue', 'KO_definition']
    )
    # The genes were assigned the K number that showed the most significant e-value.
    # If there was no K number with a score above the threshold, no annotation was assigned.
    filt_annot = annot.loc[
        annot[annot['star'].notnull()].groupby('gene_name').apply(lambda v: v.evalue.idxmin()), 'KO'
    ].value_counts()
    return gcf, filt_annot
    
from multiprocessing import Pool

with Pool(100) as pool:
    ko_sets = pd.DataFrame(
        dict(tqdm(pool.imap_unordered(load_annot, metadata.acc['refseq']), total=len(metadata.acc))), 
        dtype=pd.Int64Dtype()
    ).fillna(0).astype(int)

ko_sets.to_pickle(path2.data/'kofamscan'/'summary.pkl.bz2')
# Out:
#   0%|          | 0/2624 [00:00<?, ?it/s]

# %%
idp_summary = pd.read_pickle(
    path2.data/'iupred2a'/'summary.pkl.bz2'
).swaplevel(0,1,axis=1).swaplevel(1,2,axis=1).sort_index(axis=1)

# %%
idp_fw2rc1 = idp_summary[30,0.5].loc[[4,8]].sum() / idp_summary[30,0].loc[[4,8]].sum()
ko_corr = ko_sets.T.apply(partial(idp_fw2rc1.corr, method='spearman')).rename('rho')

# %%
ko_list = pd.read_csv(path2.metadata/'ko_list', sep='\t', index_col=0)
results = pd.concat([ko_corr, ko_list['definition']], axis=1).dropna().sort_values(by='rho')

# %%
with pd.option_context('display.max_rows', 100, 'display.max_colwidth', 150):
    display(results.iloc[-1:-101:-1])
    display(results.iloc[0:100])
# Out:
#              rho  \
# K14162  0.639115
# K00344  0.632878
# K01692  0.620871
# K05524  0.607644
# K01496  0.602390
# K14998  0.596191
# K05838  0.595265
# K01214  0.584397
# K12510  0.584232
# K06980  0.582072
# K01011  0.580310
# K10563  0.572592
# K00982  0.567282
# K07157  0.566929
# K02283  0.566378
# K03574  0.565144
# K16147  0.560440
# K01187  0.559058
# K02274  0.558092
# K12503  0.554448
# K00332  0.554129
# K06044  0.553212
# K14267  0.552670
# K01426  0.549918
# K00697  0.549540
# K22934  0.548323
# K18955  0.547105
# K01236  0.546522
# K02351  0.543754
# K05602  0.543663
# K08300  0.542714
# K07503  0.542110
# K07776  0.540169
# K03636  0.539866
# K08372  0.538680
# K13787  0.537098
# K05522  0.536040
# K03727  0.534377
# K00817  0.533695
# K22297  0.533442
# K18476  0.531708
# K01681  0.531424
# K06117  0.531387
# K07654  0.531123
# K03724  0.529844
# K07670  0.529749
# K13633  0.528815
# K03889  0.528753
# K03890  0.528533
# K13572  0.528410
# K03891  0.528372
# K24017  0.528246
# K07768  0.527819
# K20469  0.527647
# K13573  0.527540
# K00796  0.527262
# K01554  0.527097
# K08744  0.526081
# K01971  0.525809
# K09796  0.524795
# K23842  0.524490
# K01897  0.524485
# K14161  0.522221
# K11414  0.521140
# K00626  0.521133
# K05343  0.520278
# K11611  0.519614
# K00529  0.518049
# K02483  0.517764
# K00059  0.517191
# K01596  0.514562
# K18917  0.514482
# K18455  0.513838
# K23980  0.512600
# K01087  0.511448
# K06048  0.511131
# K18290  0.510575
# K15526  0.510022
# K15520  0.509596
# K01915  0.509118
# K02484  0.508277
# K00336  0.508081
# K00528  0.506429
# K10007  0.506342
# K01724  0.505709
# K00163  0.505335
# K09927  0.504784
# K13571  0.503369
# K13570  0.502718
# K09791  0.501404
# K13527  0.500099
# K06020  0.500093
# K12234  0.498765
# K09009  0.498224
# K02279  0.498003
# K20814  0.497712
# K05275  0.497622
# K02276  0.497522
# K08683  0.497152
# K01069  0.496369
#
#                                                                                                                           definition
# K14162                                                                                       error-prone DNA polymerase [EC:2.7.7.7]
# K00344                                                                                          NADPH:quinone reductase [EC:1.6.5.5]
# K01692                                                                                             enoyl-CoA hydratase [EC:4.2.1.17]
# K05524                                                                                                                    ferredoxin
# K01496                                                                               phosphoribosyl-AMP cyclohydrolase [EC:3.5.4.19]
# K14998                                                                                                surfeit locus 1 family protein
# K05838                                                                                                          putative thioredoxin
# K01214                                                                                                      isoamylase [EC:3.2.1.68]
# K12510                                                                                                     tight adherence protein B
# K06980                                                                                                   tRNA-modifying protein YgfZ
# K01011                                                         thiosulfate/3-mercaptopyruvate sulfurtransferase [EC:2.8.1.1 2.8.1.2]
# K10563                                                                   formamidopyrimidine-DNA glycosylase [EC:3.2.2.23 4.2.99.18]
# K00982  [glutamine synthetase] adenylyltransferase / [glutamine synthetase]-adenylyl-L-tyrosine phosphorylase [EC:2.7.7.42 2.7.7.89]
# K07157                                                                                                       uncharacterized protein
# K02283                                                                                      pilus assembly protein CpaF [EC:7.4.2.8]
# K03574                                                                                        8-oxo-dGTP diphosphatase [EC:3.6.1.55]
# K16147                                                                        starch synthase (maltosyl-transferring) [EC:2.4.99.16]
# K01187                                                                                               alpha-glucosidase [EC:3.2.1.20]
# K02274                                                                                   cytochrome c oxidase subunit I [EC:7.1.1.9]
# K12503                                                                    short-chain Z-isoprenyl diphosphate synthase [EC:2.5.1.68]
# K00332                                                                            NADH-quinone oxidoreductase subunit C [EC:7.1.1.2]
# K06044                                                                 (1->4)-alpha-D-glucan 1-alpha-D-glucosylmutase [EC:5.4.99.15]
# K14267                                                                      N-succinyldiaminopimelate aminotransferase [EC:2.6.1.17]
# K01426                                                                                                          amidase [EC:3.5.1.4]
# K00697                                                                        trehalose 6-phosphate synthase [EC:2.4.1.15 2.4.1.347]
# K22934                                                                                           alpha,alpha-trehalase [EC:3.2.1.28]
# K18955                                                WhiB family transcriptional regulator, redox-sensing transcriptional regulator
# K01236                                                                        maltooligosyltrehalose trehalohydrolase [EC:3.2.1.141]
# K02351                                                                                                     putative membrane protein
# K05602                                                                                          histidinol-phosphatase [EC:3.1.3.15]
# K08300                                                                                                 ribonuclease E [EC:3.1.26.12]
# K07503                                                                                                     endonuclease [EC:3.1.-.-]
# K07776                                                                   two-component system, OmpR family, response regulator RegX3
# K03636                                                                                                        sulfur-carrier protein
# K08372                                                                                   putative serine protease PepD [EC:3.4.21.-]
# K13787                                                    geranylgeranyl diphosphate synthase, type I [EC:2.5.1.1 2.5.1.10 2.5.1.29]
# K05522                                                                                      endonuclease VIII [EC:3.2.2.- 4.2.99.18]
# K03727                                                                                  ATP-dependent RNA helicase HelY [EC:3.6.4.-]
# K00817                                                                            histidinol-phosphate aminotransferase [EC:2.6.1.9]
# K22297                                                             Fur family transcriptional regulator, stress-responsive regulator
# K18476                                                    TetR/AcrR family transcriptional regulator, tetracycline repressor protein
# K01681                                                                                              aconitate hydratase [EC:4.2.1.3]
# K06117                                                                                          glycerol-1-phosphatase [EC:3.1.3.21]
# K07654                                                 two-component system, OmpR family, sensor histidine kinase MtrB [EC:2.7.13.3]
# K03724                                                                 ATP-dependent helicase Lhr and Lhr-like helicase [EC:3.6.4.-]
# K07670                                                                    two-component system, OmpR family, response regulator MtrA
# K13633                                                         AraC family transcriptional regulator, transcriptional activator FtrA
# K03889                                                                         ubiquinol-cytochrome c reductase cytochrome c subunit
# K03890                                                                          ubiquinol-cytochrome c reductase iron-sulfur subunit
# K13572                                                                                                 proteasome accessory factor B
# K03891                                                                         ubiquinol-cytochrome c reductase cytochrome b subunit
# K24017                                                                             phosphoribosyl isomerase A [EC:5.3.1.16 5.3.1.24]
# K07768                                                two-component system, OmpR family, sensor histidine kinase SenX3 [EC:2.7.13.3]
# K20469                                                                                                     putative heme transporter
# K13573                                                                                                 proteasome accessory factor C
# K00796                                                                                        dihydropteroate synthase [EC:2.5.1.15]
# K01554                                                                                          8-oxo-dGDP phosphatase [EC:3.6.1.58]
# K08744                                                                              cardiolipin synthase (CMP-forming) [EC:2.7.8.41]
# K01971                                                             bifunctional non-homologous end joining protein LigD [EC:6.5.1.1]
# K09796                                                                                                periplasmic copper chaperone A
# K23842                                                                                  NAD(P)H dehydrogenase (quinone) [EC:1.6.5.2]
# K01897                                                                                   long-chain acyl-CoA synthetase [EC:6.2.1.3]
# K14161                                                                                                                  protein ImuB
# K11414                                                                   NAD+-dependent protein deacetylase sirtuin 4 [EC:2.3.1.286]
# K00626                                                                                   acetyl-CoA C-acetyltransferase [EC:2.3.1.9]
# K05343                                                    maltose alpha-D-glucosyltransferase / alpha-amylase [EC:5.4.99.16 3.2.1.1]
# K11611                                                        meromycolic acid enoyl-[acyl-carrier-protein] reductase [EC:1.3.1.118]
# K00529                                   3-phenylpropionate/trans-cinnamate dioxygenase ferredoxin reductase component [EC:1.18.1.3]
# K02483                                                                         two-component system, OmpR family, response regulator
# K00059                                                                     3-oxoacyl-[acyl-carrier protein] reductase [EC:1.1.1.100]
# K01596                                                                         phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]
# K18917                                                                                                     mycoredoxin [EC:1.20.4.3]
# K18455                                                                                  mycothiol S-conjugate amidase [EC:3.5.1.115]
# K23980                                                                       cysteinylglycine-S-conjugate dipeptidase [EC:3.4.13.23]
# K01087                                                                               trehalose 6-phosphate phosphatase [EC:3.1.3.12]
# K06048                                                   glutamate---cysteine ligase / carboxylate-amine ligase [EC:6.3.2.2 6.3.-.-]
# K18290                                                                                          itaconyl-CoA hydratase [EC:4.2.1.56]
# K15526                                       L-cysteine:1D-myo-inositol 2-amino-2-deoxy-alpha-D-glucopyranoside ligase [EC:6.3.1.13]
# K15520                                                                                             mycothiol synthase [EC:2.3.1.189]
# K01915                                                                                             glutamine synthetase [EC:6.3.1.2]
# K02484                                                                two-component system, OmpR family, sensor kinase [EC:2.7.13.3]
# K00336                                                                            NADH-quinone oxidoreductase subunit G [EC:7.1.1.2]
# K00528                                                                ferredoxin/flavodoxin---NADP+ reductase [EC:1.18.1.2 1.19.1.1]
# K10007                                                                                   glutamate transport system permease protein
# K01724                                                                       4a-hydroxytetrahydrobiopterin dehydratase [EC:4.2.1.96]
# K00163                                                                              pyruvate dehydrogenase E1 component [EC:1.2.4.1]
# K09927                                                                                                       uncharacterized protein
# K13571                                                                                   proteasome accessory factor A [EC:6.3.1.19]
# K13570                                                                                        prokaryotic ubiquitin-like protein Pup
# K09791                                                                                                       uncharacterized protein
# K13527                                                                                                  proteasome-associated ATPase
# K06020                                                                          energy-dependent translational throttle protein EttA
# K12234                          coenzyme F420-0:L-glutamate ligase / coenzyme F420-1:gamma-L-glutamate ligase [EC:6.3.2.31 6.3.2.34]
# K09009                                                                                                       uncharacterized protein
# K02279                                                                                                   pilus assembly protein CpaB
# K20814                                                                                             Pup amidohydrolase [EC:3.5.1.119]
# K05275                                                                                      pyridoxine 4-dehydrogenase [EC:1.1.1.65]
# K02276                                                                                 cytochrome c oxidase subunit III [EC:7.1.1.9]
# K08683                         3-hydroxyacyl-CoA dehydrogenase / 3-hydroxy-2-methylbutyryl-CoA dehydrogenase [EC:1.1.1.35 1.1.1.178]
# K01069                                                                                 hydroxyacylglutathione hydrolase [EC:3.1.2.6]
#              rho  \
# K22391 -0.543406
# K03495 -0.531573
# K07462 -0.524237
# K07456 -0.516295
# K00243 -0.506743
# K03650 -0.497353
# K00876 -0.483929
# K01893 -0.481589
# K03978 -0.480697
# K15460 -0.476195
# K18682 -0.460009
# K03590 -0.451099
# K01493 -0.437156
# K13052 -0.429343
# K03763 -0.423195
# K00850 -0.422867
# K11145 -0.422469
# K09787 -0.417845
# K02970 -0.409178
# K02687 -0.406506
# K16786 -0.404776
# K07584 -0.402347
# K00949 -0.401148
# K16787 -0.399916
# K14540 -0.398992
# K05985 -0.397375
# K03555 -0.396384
# K22927 -0.396155
# K01270 -0.393097
# K19005 -0.392943
# K03572 -0.392904
# K23675 -0.391107
# K15633 -0.388558
# K18672 -0.386935
# K12573 -0.384791
# K00783 -0.383575
# K01258 -0.382979
# K06885 -0.381727
# K02824 -0.377236
# K06967 -0.376228
# K09698 -0.372647
# K02086 -0.372164
# K09685 -0.370609
# K03151 -0.369742
# K11755 -0.368850
# K03311 -0.360733
# K15986 -0.354591
# K03315 -0.349404
# K06973 -0.348744
# K07139 -0.347681
# K03700 -0.346864
# K03570 -0.340265
# K02371 -0.339435
# K07706 -0.337964
# K06948 -0.335462
# K21636 -0.335416
# K01597 -0.334808
# K03708 -0.333094
# K18692 -0.329170
# K07668 -0.328609
# K06881 -0.328311
# K07568 -0.327934
# K16509 -0.327181
# K06286 -0.326544
# K16789 -0.326249
# K07533 -0.325411
# K07652 -0.325358
# K07015 -0.324907
# K05311 -0.324854
# K03706 -0.324573
# K07444 -0.324444
# K10679 -0.324087
# K09976 -0.319820
# K06950 -0.318262
# K03346 -0.318146
# K02245 -0.317839
# K02248 -0.317723
# K02217 -0.316988
# K03816 -0.316187
# K24180 -0.315052
# K02244 -0.314326
# K11144 -0.313856
# K07173 -0.313843
# K02243 -0.312938
# K18941 -0.311895
# K22132 -0.311530
# K03048 -0.311315
# K16511 -0.310789
# K18940 -0.308572
# K02240 -0.308077
# K09765 -0.306262
# K18889 -0.305924
# K08303 -0.305905
# K09825 -0.305080
# K00054 -0.304985
# K18890 -0.304807
# K07105 -0.303495
# K07705 -0.302513
# K01914 -0.299791
# K07035 -0.299717
#
#                                                                                                 definition
# K22391                                                                  GTP cyclohydrolase I [EC:3.5.4.16]
# K03495                                         tRNA uridine 5-carboxymethylaminomethyl modification enzyme
# K07462                                               single-stranded-DNA-specific exonuclease [EC:3.1.-.-]
# K07456                                                                   DNA mismatch repair protein MutS2
# K00243                                                                             uncharacterized protein
# K03650                                                               tRNA modification GTPase [EC:3.6.-.-]
# K00876                                                                        uridine kinase [EC:2.7.1.48]
# K01893                                                           asparaginyl-tRNA synthetase [EC:6.1.1.22]
# K03978                                                                                 GTP-binding protein
# K15460                                            tRNA1Val (adenine37-N6)-methyltransferase [EC:2.1.1.223]
# K18682                                                                         ribonucrease Y [EC:3.1.-.-]
# K03590                                                                          cell division protein FtsA
# K01493                                                                        dCMP deaminase [EC:3.5.4.12]
# K13052                                                                         cell division protein DivIC
# K03763                                   DNA polymerase III subunit alpha, Gram-positive type [EC:2.7.7.7]
# K00850                                                               6-phosphofructokinase 1 [EC:2.7.1.11]
# K11145                                                       ribonuclease III family protein [EC:3.1.26.-]
# K09787                                                                             uncharacterized protein
# K02970                                                                 small subunit ribosomal protein S21
# K02687                                                ribosomal protein L11 methyltransferase [EC:2.1.1.-]
# K16786                            energy-coupling factor transport system ATP-binding protein [EC:7.-.-.-]
# K07584                                                                             uncharacterized protein
# K00949                                                             thiamine pyrophosphokinase [EC:2.7.6.2]
# K16787                            energy-coupling factor transport system ATP-binding protein [EC:7.-.-.-]
# K14540                                                                        ribosome biogenesis GTPase A
# K05985                                                                       ribonuclease M5 [EC:3.1.26.8]
# K03555                                                                    DNA mismatch repair protein MutS
# K22927                                                       cyclic-di-AMP phosphodiesterase [EC:3.1.4.59]
# K01270                                                                         dipeptidase D [EC:3.4.13.-]
# K19005                                                            lipoteichoic acid synthase [EC:2.7.8.20]
# K03572                                                                    DNA mismatch repair protein MutL
# K23675                                                                              riboflavin transporter
# K15633                           2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]
# K18672                                                                   diadenylate cyclase [EC:2.7.7.85]
# K12573                                                                        ribonuclease R [EC:3.1.13.1]
# K00783                                    23S rRNA (pseudouridine1915-N3)-methyltransferase [EC:2.1.1.177]
# K01258                                                             tripeptide aminopeptidase [EC:3.4.11.4]
# K06885                                                                             uncharacterized protein
# K02824                                                                                     uracil permease
# K06967                                                tRNA (adenine22-N1)-methyltransferase [EC:2.1.1.217]
# K09698                                            nondiscriminating glutamyl-tRNA synthetase [EC:6.1.1.24]
# K02086                                                                             DNA replication protein
# K09685                                                                             purine operon repressor
# K03151                                                        tRNA uracil 4-sulfurtransferase [EC:2.8.1.4]
# K11755  phosphoribosyl-AMP cyclohydrolase / phosphoribosyl-ATP pyrophosphohydrolase [EC:3.5.4.19 3.6.1.31]
# K03311                                          branched-chain amino acid:cation transporter, LIVCS family
# K15986                                          manganese-dependent inorganic pyrophosphatase [EC:3.6.1.1]
# K03315                                                                      Na+:H+ antiporter, NhaC family
# K06973                                                                             uncharacterized protein
# K07139                                                                             uncharacterized protein
# K03700                                                                             recombination protein U
# K03570                                                                  rod shape-determining protein MreC
# K02371                                              enoyl-[acyl-carrier protein] reductase II [EC:1.3.1.9]
# K07706                      two-component system, LytTR family, sensor histidine kinase AgrC [EC:2.7.13.3]
# K06948                                                                        30S ribosome assembly GTPase
# K21636                                       ribonucleoside-triphosphate reductase (formate) [EC:1.1.98.6]
# K01597                                                     diphosphomevalonate decarboxylase [EC:4.1.1.33]
# K03708                                         transcriptional regulator of stress and heat shock response
# K18692                                                       ATP-dependent RNA helicase CshB [EC:3.6.4.13]
# K07668                                          two-component system, OmpR family, response regulator VicR
# K06881                       bifunctional oligoribonuclease and PAP phosphatase NrnA [EC:3.1.3.7 3.1.13.3]
# K07568                               S-adenosylmethionine:tRNA ribosyltransferase-isomerase [EC:2.4.99.17]
# K16509                                                                              regulatory protein spx
# K06286                                                                  septation ring formation regulator
# K16789                                                                                thiamine transporter
# K07533                                                                   foldase protein PrsA [EC:5.2.1.8]
# K07652                       two-component system, OmpR family, sensor histidine kinase VicK [EC:2.7.13.3]
# K07015                                                                             uncharacterized protein
# K05311                                                                  central glycolytic genes regulator
# K03706                                                               transcriptional pleiotropic repressor
# K07444                                             putative N6-adenine-specific DNA methylase [EC:2.1.1.-]
# K10679                                   nitroreductase / dihydropteridine reductase [EC:1.-.-.- 1.5.1.34]
# K09976                                                                             uncharacterized protein
# K06950                                                                             uncharacterized protein
# K03346                                              replication initiation and membrane attachment protein
# K02245                                                                            competence protein ComGC
# K02248                                                                            competence protein ComGF
# K02217                                                                              ferritin [EC:1.16.3.2]
# K03816                                                    xanthine phosphoribosyltransferase [EC:2.4.2.22]
# K24180                                                                malate permease and related proteins
# K02244                                                                            competence protein ComGB
# K11144                                                                             primosomal protein DnaI
# K07173                                                           S-ribosylhomocysteine lyase [EC:4.4.1.21]
# K02243                                                                            competence protein ComGA
# K18941                                          two-component system, OmpR family, response regulator ArlR
# K22132                                                         tRNA threonylcarbamoyladenosine dehydratase
# K03048                                                           DNA-directed RNA polymerase subunit delta
# K16511                                                                            adapter protein MecA 1/2
# K18940                       two-component system, OmpR family, sensor histidine kinase ArlS [EC:2.7.13.3]
# K02240                                                                            competence protein ComFA
# K09765                                                             epoxyqueuosine reductase [EC:1.17.99.6]
# K18889                                            ATP-binding cassette, subfamily B, multidrug efflux pump
# K08303                                                                      putative protease [EC:3.4.-.-]
# K09825                            Fur family transcriptional regulator, peroxide stress response regulator
# K00054                                                   hydroxymethylglutaryl-CoA reductase [EC:1.1.1.88]
# K18890                                            ATP-binding cassette, subfamily B, multidrug efflux pump
# K07105                                                                             uncharacterized protein
# K07705                                         two-component system, LytTR family, response regulator LytT
# K01914                                                              aspartate--ammonia ligase [EC:6.3.1.1]
# K07035                                                                             uncharacterized protein

# %% [markdown]
# - Reproducibility was confirmed.
# - The table will be formatted more precisely somewhere in this workspace.
